# %% [markdown]
# # Geocoding with GeoPy

# %%
# install geopy
# !pip install geopy
# Out:
# Requirement already satisfied: geopy in c:\users\colto\anaconda3\lib\site-packages (2.4.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\users\colto\anaconda3\lib\site-packages (from geopy) (2.0)

# %%
import pandas as pd

# Import Nominatim ("Name" in Latin) and initialize
# Though most of these services require an API key, Nominatim, which uses OpenStreetMap data, does not,
# which is why we’re going to use it here. But we still need to create a unique application name.
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="Wenyi Shang's mapping app", timeout=2)

# %%
# Locate a specific location
location = geolocator.geocode("East Daniel Street, Champaign")
location
# Out:
# Location(East Daniel Street, Campustown, Champaign, Champaign County, Illinois, 61820, United States, (40.1079572, -88.2319022, 0.0))

# %%
# Full information
location.raw
# Out:
# {'place_id': 27867261,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#  'osm_type': 'way',
#  'osm_id': 745458640,
#  'lat': '40.1079572',
#  'lon': '-88.2319022',
#  'class': 'highway',
#  'type': 'residential',
#  'place_rank': 26,
#  'importance': 0.10000999999999993,
#  'addresstype': 'road',
#  'name': 'East Daniel Street',
#  'display_name': 'East Daniel Street, Campustown, Champaign, Champaign County, Illinois, 61820, United States',
#  'boundingbox': ['40.1079500', '40.1079691', '-88.2335000', '-88.2303450']}

# %%
print(location.address)
print(location.raw['lat'])
print(location.raw['lon'])
print(location.raw['class'])
print(location.raw['type'])
# Out:
# East Daniel Street, Campustown, Champaign, Champaign County, Illinois, 61820, United States
# 40.1079572
# -88.2319022
# highway
# residential

# %%
possible_locations = geolocator.geocode("East Daniel Street", exactly_one=False)
for location in possible_locations:
    print(location.address)
# Out:
# East Daniel Street, Bloomington, Monroe County, Indiana, 47401, United States
# East Daniel Street, Campustown, Champaign, Champaign County, Illinois, 61820, United States
# East Daniel Street, Seniorland, Champaign, Champaign County, Illinois, 61820, United States
# East Daniel Street, Collinwood, Wayne County, Middle Tennessee, Tennessee, 38450, United States
# East Daniel Street, Hinton, Boone County, Missouri, United States
# East Daniel Street, Greene County, Missouri, 65803, United States
# East Daniel Street, Uvalde, Uvalde County, Texas, 78801, United States
# East Daniel Street, North Uvalde Colonia, Uvalde, Uvalde County, Texas, 78801, United States
# East Daniel Street, Albany, Gentry County, Missouri, 64402, United States
# East Daniel Street, Silver City, Grant County, New Mexico, 88062, United States

# %%
Illini_Union = geolocator.geocode('Illini Union')
Illini_Union.address
# Out:
# 'Illini Union, 1401, West Green Street, Urbana, Champaign County, Illinois, 61801, United States'

# %% [markdown]
# # Task 1

# %%
# Create a dataframe to store the geographical locations of a list of places in Champaign.
# The dataframe "Champaign_df" should contain 6 columns:
# "Place", "Address" (obtained by ".address"), "Latitude", "Longitude", "Class", "Type" (obtained by corresponding keys in ".raw")

Champaign_places = ['Foellinger Auditorium', 'Altgeld Hall', 'Krannert Center for the Performing Arts', 
                    'University of Illinois Urbana-Champaign University Library', 'Japan House']

geolocator = Nominatim(user_agent="champaign_locator")

place_list = []
address_list = []
latitude_list = []
longitude_list = []
class_list = []
type_list = []

Cham = geolocator.geocode('Champaign, Illinois')

for place in Champaign_places:
    location = geolocator.geocode(place)
    place_list.append(place)
    address_list.append(location.address)
    latitude_list.append(location.latitude)
    longitude_list.append(location.longitude)
    location_raw = location.raw
    class_list.append(location_raw.get('class'))
    type_list.append(location_raw.get('type'))

Champaign_df = pd.DataFrame({
    'Place': place_list,
    'Address': address_list,
    'Latitude': latitude_list,
    'Longitude': longitude_list,
    'Class': class_list,
    'Type': type_list
})

print(Champaign_df)
# Out:
#                                                Place  \
# 0                              Foellinger Auditorium
# 1                                       Altgeld Hall
# 2            Krannert Center for the Performing Arts
# 3  University of Illinois Urbana-Champaign Univer...
# 4                                        Japan House
#
#                                              Address   Latitude  Longitude  \
# 0  Foellinger Auditorium, 709, South Mathews Aven...  40.105941 -88.227182
# 1  Altgeld Hall, 1409, West Green Street, Urbana,...  40.109328 -88.228328
# 2  Krannert Center for the Performing Arts, 500, ...  40.108011 -88.222528
# 3  Main Library, 1408, West Gregory Drive, Urbana...  40.104681 -88.228990
# 4  Japan House, 101-111, Kensington High Street, ...  51.501350  -0.191682
#
#       Class              Type
# 0   amenity           theatre
# 1  building        university
# 2   amenity       arts_centre
# 3   amenity           library
# 4   amenity  community_centre

# %% [markdown]
# # Making Interactive Maps with folium

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in c:\users\colto\anaconda3\lib\site-packages (0.14.0)
# Requirement already satisfied: requests in c:\users\colto\anaconda3\lib\site-packages (from folium) (2.27.1)
# Requirement already satisfied: branca>=0.6.0 in c:\users\colto\anaconda3\lib\site-packages (from folium) (0.6.0)
# Requirement already satisfied: numpy in c:\users\colto\anaconda3\lib\site-packages (from folium) (1.21.5)
# Requirement already satisfied: jinja2>=2.9 in c:\users\colto\anaconda3\lib\site-packages (from folium) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\colto\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\colto\anaconda3\lib\site-packages (from requests->folium) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\colto\anaconda3\lib\site-packages (from requests->folium) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\colto\anaconda3\lib\site-packages (from requests->folium) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\colto\anaconda3\lib\site-packages (from requests->folium) (2.0.4)

# %%
import folium

# %%
Champaign = geolocator.geocode('Champaign')
Champaign
# Out:
# Location(Champaign, Champaign County, Illinois, United States, (40.1164841, -88.2430932, 0.0))

# %%
Champaign = geolocator.geocode('Champaign')
champaign_map
# Out:
# Location(Champaign, Champaign County, Illinois, United States, (40.1164841, -88.2430932, 0.0))

# %%
# Add a marker
folium.Marker(location=([Illini_Union.raw['lat'], Illini_Union.raw['lon']]), tooltip = 'click me', 
              popup="Illini Union").add_to(champaign_map)
champaign_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_175a2a6e3a0a5ceb1b66f082347117cb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_175a2a6e3a0a5ceb1b66f082347117cb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_175a2a6e3a0a5ceb1b66f082347117cb = L.map(
#                 &quot;map_175a2a6e3a0a5ceb1b66f082347117cb&quot;,
#                 {
#                     center: [40.1164841, -88.2430932],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_10a952d258139a25f336b2ae5ea4ede6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_175a2a6e3a0a5ceb1b66f082347117cb);
#
#
#             var marker_d9c82b43c9e068c13960d41d94fb9384 = L.marker(
#                 [40.105941200000004, -88.22718219082223],
#                 {}
#             ).addTo(map_175a2a6e3a0a5ceb1b66f082347117cb);
#
#
#         var popup_57921d0d2083ebd4f03920865ac484d7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cde95cd4ace26794a8aa117ca4d0458d = $(`&lt;div id=&quot;html_cde95cd4ace26794a8aa117ca4d0458d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Foellinger Auditorium&lt;/div&gt;`)[0];
#                 popup_57921d0d2083ebd4f03920865ac484d7.setContent(html_cde95cd4ace26794a8aa117ca4d0458d);
#
#
#
#         marker_d9c82b43c9e068c13960d41d94fb9384.bindPopup(popup_57921d0d2083ebd4f03920865ac484d7)
#         ;
#
#
#
#
#             var marker_fa3f9fa04adebfc43632331302fda0fa = L.marker(
#                 [40.10932815, -88.22832765271605],
#                 {}
#             ).addTo(map_175a2a6e3a0a5ceb1b66f082347117cb);
#
#
#         var popup_2b921ea5a44cdd8654cd244a3d2f2f64 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0f2f7ee2c9e66f233cd4ebd50a10b746 = $(`&lt;div id=&quot;html_0f2f7ee2c9e66f233cd4ebd50a10b746&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Altgeld Hall&lt;/div&gt;`)[0];
#                 popup_2b921ea5a44cdd8654cd244a3d2f2f64.setContent(html_0f2f7ee2c9e66f233cd4ebd50a10b746);
#
#
#
#         marker_fa3f9fa04adebfc43632331302fda0fa.bindPopup(popup_2b921ea5a44cdd8654cd244a3d2f2f64)
#         ;
#
#
#
#
#             var marker_afbfe8ae05eb00ab0315dd0d248a28d2 = L.marker(
#                 [40.1080112, -88.22252800649827],
#                 {}
#             ).addTo(map_175a2a6e3a0a5ceb1b66f082347117cb);
#
#
#         var popup_b3b7bbae54080c69315757e5a6f95461 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_730b89fd3763781834e4c09b3e20fd3c = $(`&lt;div id=&quot;html_730b89fd3763781834e4c09b3e20fd3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Krannert Center for the Performing Arts&lt;/div&gt;`)[0];
#                 popup_b3b7bbae54080c69315757e5a6f95461.setContent(html_730b89fd3763781834e4c09b3e20fd3c);
#
#
#
#         marker_afbfe8ae05eb00ab0315dd0d248a28d2.bindPopup(popup_b3b7bbae54080c69315757e5a6f95461)
#         ;
#
#
#
#
#             var marker_26450b09b026265b708c76827605bd87 = L.marker(
#                 [40.1046808, -88.22899004217172],
#                 {}
#             ).addTo(map_175a2a6e3a0a5ceb1b66f082347117cb);
#
#
#         var popup_bdd7d7f969896cc16c6025b4c36f963f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a3ed95f8fc7aa3f896a5325d171b995e = $(`&lt;div id=&quot;html_a3ed95f8fc7aa3f896a5325d171b995e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;University of Illinois Urbana-Champaign University Library&lt;/div&gt;`)[0];
#                 popup_bdd7d7f969896cc16c6025b4c36f963f.setContent(html_a3ed95f8fc7aa3f896a5325d171b995e);
#
#
#
#         marker_26450b09b026265b708c76827605bd87.bindPopup(popup_bdd7d7f969896cc16c6025b4c36f963f)
#         ;
#
#
#
#
#             var marker_ed6746953cc96c668426b4a3a138fd3d = L.marker(
#                 [51.5013496, -0.1916822],
#                 {}
#             ).addTo(map_175a2a6e3a0a5ceb1b66f082347117cb);
#
#
#         var popup_d0e435d7c674ca7bf1e613efc67f801d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_01d5bc1ec8b3062d03b9598f42ea557f = $(`&lt;div id=&quot;html_01d5bc1ec8b3062d03b9598f42ea557f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Japan House&lt;/div&gt;`)[0];
#                 popup_d0e435d7c674ca7bf1e613efc67f801d.setContent(html_01d5bc1ec8b3062d03b9598f42ea557f);
#
#
#
#         marker_ed6746953cc96c668426b4a3a138fd3d.bindPopup(popup_d0e435d7c674ca7bf1e613efc67f801d)
#         ;

# %%
champaign_map.save("Data/Champaign-map.html")

# %% [markdown]
# # Task 2

# %%
# First, reload the champaign_map to drop the added Marker of Illini Union
# Then for each place in Champaign_df you created for Task 1, add it as a Marker, with location defined by the
# latitude and longitude values in the DataFrame, popup value as the place names in the dataframe



champaign_map = folium.Map(location=[Cham.latitude, Cham.longitude], zoom_start=14)

for i in range(len(Champaign_df)):
    folium.Marker(
        location=[Champaign_df['Latitude'][i], Champaign_df['Longitude'][i]],
        popup=Champaign_df['Place'][i],
    ).add_to(champaign_map)

champaign_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_101f7c9985a98252943285e2747d2ab3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_101f7c9985a98252943285e2747d2ab3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_101f7c9985a98252943285e2747d2ab3 = L.map(
#                 &quot;map_101f7c9985a98252943285e2747d2ab3&quot;,
#                 {
#                     center: [40.1164841, -88.2430932],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fbfeb0a2d8a47ddc5f170fb32e96f1b4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_101f7c9985a98252943285e2747d2ab3);
#
#
#             var marker_ff54e37c4881fd2be0d943c173f35069 = L.marker(
#                 [40.105941200000004, -88.22718219082223],
#                 {}
#             ).addTo(map_101f7c9985a98252943285e2747d2ab3);
#
#
#         var popup_71790b0a79add0e39533ef7c5013647d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1140dd862bbec8b1c7233e30c553bd0c = $(`&lt;div id=&quot;html_1140dd862bbec8b1c7233e30c553bd0c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Foellinger Auditorium&lt;/div&gt;`)[0];
#                 popup_71790b0a79add0e39533ef7c5013647d.setContent(html_1140dd862bbec8b1c7233e30c553bd0c);
#
#
#
#         marker_ff54e37c4881fd2be0d943c173f35069.bindPopup(popup_71790b0a79add0e39533ef7c5013647d)
#         ;
#
#
#
#
#             var marker_b716a294287a991dd2352443430d3ec5 = L.marker(
#                 [40.10932815, -88.22832765271605],
#                 {}
#             ).addTo(map_101f7c9985a98252943285e2747d2ab3);
#
#
#         var popup_4528c0cbebee39b51c29469f543daab8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_714c8d49f206f3df96b368f9b1c37547 = $(`&lt;div id=&quot;html_714c8d49f206f3df96b368f9b1c37547&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Altgeld Hall&lt;/div&gt;`)[0];
#                 popup_4528c0cbebee39b51c29469f543daab8.setContent(html_714c8d49f206f3df96b368f9b1c37547);
#
#
#
#         marker_b716a294287a991dd2352443430d3ec5.bindPopup(popup_4528c0cbebee39b51c29469f543daab8)
#         ;
#
#
#
#
#             var marker_d06ab542b4cb189d650cd4aeb9e976c9 = L.marker(
#                 [40.1080112, -88.22252800649827],
#                 {}
#             ).addTo(map_101f7c9985a98252943285e2747d2ab3);
#
#
#         var popup_fccf09f29a43db8373c1482a03135a04 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6db6e83fb3fff7edb830e17ed584d966 = $(`&lt;div id=&quot;html_6db6e83fb3fff7edb830e17ed584d966&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Krannert Center for the Performing Arts&lt;/div&gt;`)[0];
#                 popup_fccf09f29a43db8373c1482a03135a04.setContent(html_6db6e83fb3fff7edb830e17ed584d966);
#
#
#
#         marker_d06ab542b4cb189d650cd4aeb9e976c9.bindPopup(popup_fccf09f29a43db8373c1482a03135a04)
#         ;
#
#
#
#
#             var marker_0e9917fa6ae6d68eeb626b000e05dca3 = L.marker(
#                 [40.1046808, -88.22899004217172],
#                 {}
#             ).addTo(map_101f7c9985a98252943285e2747d2ab3);
#
#
#         var popup_e177fa679c004ccffc44419ba4080535 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1bf88bd8298cfa98a8a5cf7ffde42aed = $(`&lt;div id=&quot;html_1bf88bd8298cfa98a8a5cf7ffde42aed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;University of Illinois Urbana-Champaign University Library&lt;/div&gt;`)[0];
#                 popup_e177fa679c004ccffc44419ba4080535.setContent(html_1bf88bd8298cfa98a8a5cf7ffde42aed);
#
#
#
#         marker_0e9917fa6ae6d68eeb626b000e05dca3.bindPopup(popup_e177fa679c004ccffc44419ba4080535)
#         ;
#
#
#
#
#             var marker_b14b3dca943d3ce56626cb9dd71ad5dd = L.marker(
#                 [51.5013496, -0.1916822],
#                 {}
#             ).addTo(map_101f7c9985a98252943285e2747d2ab3);
#
#
#         var popup_dffb88e45842a1767a04b5d61d143c7d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_32b7322ef5b0145919f751769f7be51a = $(`&lt;div id=&quot;html_32b7322ef5b0145919f751769f7be51a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Japan House&lt;/div&gt;`)[0];
#                 popup_dffb88e45842a1767a04b5d61d143c7d.setContent(html_32b7322ef5b0145919f751769f7be51a);
#
#
#
#         marker_b14b3dca943d3ce56626cb9dd71ad5dd.bindPopup(popup_dffb88e45842a1767a04b5d61d143c7d)
#         ;

# %% [markdown]
# # Add a Circle Marker

# %%
# Scottish witchcraft dataset
# (http://witches.hca.ed.ac.uk/#:~:text=The%20database%20contains%20all%20people,to%20social%20and%20cultural%20history)
df = pd.read_csv('data/accused_witches.csv')
df
# Out:
#       AccusedRef AccusedSystemId  AccusedID  FirstName    LastName  \
# 0       A/EGD/10             EGD       10.0     Mareon     Quheitt
# 1      A/EGD/100             EGD      100.0       Thom    Cockburn
# 2     A/EGD/1000             EGD     1000.0  Christian  Aitkenhead
# 3     A/EGD/1001             EGD     1001.0      Janet     Ireland
# 4     A/EGD/1002             EGD     1002.0      Agnes  Hendersoun
# ...          ...             ...        ...        ...         ...
# 4378  20/10/1637             NaN        NaN        NaN         NaN
# 4379   17/2/1642             NaN        NaN        NaN         NaN
# 4380  24/10/1628             NaN        NaN        NaN         NaN
# 4381  25/10/1651             NaN        NaN        NaN         NaN
# 4382      4/1568             NaN        NaN        NaN         NaN
#
#      M_Firstname  M_Surname Alias Patronymic DesTitle  ... SocioecStatus  \
# 0         Marion      White   NaN        NaN      NaN  ...           NaN
# 1         Thomas   Cockburn   NaN        NaN      NaN  ...           NaN
# 2      Christine  Aikenhead   NaN        NaN      NaN  ...           NaN
# 3          Janet    Ireland   NaN        NaN      NaN  ...           NaN
# 4          Agnes  Henderson   NaN        NaN      NaN  ...           NaN
# ...          ...        ...   ...        ...      ...  ...           ...
# 4378         NaN        NaN   NaN        NaN      NaN  ...           NaN
# 4379         NaN        NaN   NaN        NaN      NaN  ...           NaN
# 4380         NaN        NaN   NaN        NaN      NaN  ...           NaN
# 4381         NaN        NaN   NaN        NaN      NaN  ...           NaN
# 4382         NaN        NaN   NaN        NaN      NaN  ...           NaN
#
#       Occupation  Notes  Createdby     Createdate Lastupdatedby  \
# 0            NaN    NaN        SMD  5/15/01 11:06           jhm
# 1            NaN    NaN        SMD  5/15/01 11:06           jhm
# 2            NaN    NaN        SMD  5/15/01 11:06           jhm
# 3            NaN    NaN        SMD  5/15/01 11:06           jhm
# 4            NaN    NaN        SMD  5/15/01 11:06           jhm
# ...          ...    ...        ...            ...           ...
# 4378         NaN    NaN        NaN            NaN           NaN
# 4379         NaN    NaN        NaN            NaN           NaN
# 4380         NaN    NaN        NaN            NaN           NaN
# 4381         NaN    NaN        NaN            NaN           NaN
# 4382         NaN    NaN        NaN            NaN           NaN
#
#       Lastupdatedon  Family of Accused       Cases      Date
# 0      8/9/02 11:40                NaN    C/EGD/21  3/4/1661
# 1     10/2/02 10:32                NaN   C/EGD/111      1591
# 2     10/1/02 10:48          AF/LA/150  C/EGD/1011  6/5/1628
# 3     10/1/02 10:49          AF/LA/151  C/EGD/1012  6/5/1628
# 4     10/1/02 10:50                NaN  C/EGD/1013  3/7/1628
# ...             ...                ...         ...       ...
# 4378            NaN                NaN         NaN       NaN
# 4379            NaN                NaN         NaN       NaN
# 4380            NaN                NaN         NaN       NaN
# 4381            NaN                NaN         NaN       NaN
# 4382            NaN                NaN         NaN       NaN
#
# [4383 rows x 36 columns]

# %%
# Count the number of witches accused in each county
county_witches = df.groupby("Res_county")["AccusedRef"].count()
county_witches
# Out:
# Res_county
# Aberdeen         175
# Argyll             6
# Ayr              153
# Banff              9
# Berwick          126
# Bute              54
# Caithness         52
# Clackmannan       18
# Cromarty           2
# Dumfries          78
# Dunbarton         25
# Edinburgh        374
# Elgin             28
# Fife             382
# Forfar            82
# Haddington       543
# Inverness         45
# Kincardine         2
# Kinross            7
# Kirkcudbright     35
# Lanark            77
# Linlithgow       114
# Nairn             55
# Orkney            72
# Peebles           91
# Perth            109
# Renfrew          124
# Ross              74
# Roxburgh          60
# Selkirk           21
# Shetland          28
# Stirling          53
# Sutherland        15
# Wigtown           15
# Name: AccusedRef, dtype: int64

# %%
# Obtain the latitude and longitude of each county by getting the median of the all latitude and longitude records
# under the name of that county. Median is chose so that incorrect record will be ignored
# (the incorrect data can only be the outliers and will not influence the median),
# and convert them to dictionaries.
county_latitude = df.groupby("Res_county")["latitude"].median()
county_longitude = df.groupby("Res_county")["longitude"].median()
county_latitude_dict = county_latitude.to_dict()
county_longitude_dict = county_longitude.to_dict()
print(county_latitude_dict, county_longitude_dict)
# Out:
# {'Aberdeen': 57.146262, 'Argyll': 56.4006, 'Ayr': 55.457393, 'Banff': 57.666252, 'Berwick': 55.781124, 'Bute': 55.8274, 'Caithness': 58.4389, 'Clackmannan': 56.108159, 'Cromarty': 57.6806, 'Dumfries': 55.068632, 'Dunbarton': 56.83301, 'Edinburgh': 55.92826, 'Elgin': 57.648022, 'Fife': 56.253397, 'Forfar': 56.639836, 'Haddington': 55.955755, 'Inverness': 57.479549, 'Kincardine': 56.068975, 'Kinross': 56.211141, 'Kirkcudbright': 54.835888, 'Lanark': 55.674898, 'Linlithgow': 55.9716, 'Nairn': 57.585033, 'Orkney': 58.9809, 'Peebles': 55.651467, 'Perth': 56.395704, 'Renfrew': 55.874645, 'Ross': 56.83301, 'Roxburgh': nan, 'Selkirk': 55.548073, 'Shetland': 60.305229, 'Stirling': 56.281067, 'Sutherland': 58.249999, 'Wigtown': 54.868426} {'Aberdeen': -2.136575, 'Argyll': -5.4807, 'Ayr': -4.628716, 'Banff': -2.52426, 'Berwick': -2.011552, 'Bute': -5.0936, 'Caithness': -3.0937, 'Clackmannan': -3.747183, 'Cromarty': -4.0347, 'Dumfries': -3.608237, 'Dunbarton': -4.180209, 'Edinburgh': -3.275582, 'Elgin': -3.320025, 'Fife': -3.134239, 'Forfar': -2.893115, 'Haddington': -2.783795, 'Inverness': -4.237208, 'Kincardine': -3.715198, 'Kinross': -3.425103, 'Kirkcudbright': -4.049153, 'Lanark': -3.773292, 'Linlithgow': -3.6026, 'Nairn': -3.869079, 'Orkney': -2.9605, 'Peebles': -3.191026, 'Perth': -3.435877, 'Renfrew': -4.389173, 'Ross': -4.180209, 'Roxburgh': nan, 'Selkirk': -2.839351, 'Shetland': -1.294066, 'Stirling': -4.436736, 'Sutherland': -4.499998, 'Wigtown': -4.442783}

# %%
# Create a dataframe to record the county names, number of cases, and their latitudes and longitudes
county_name = []
county_witch_num = []
county_latitude = []
county_longitude = []
for i in range(len(county_witches)):
    current_county_name = county_witches.index[i]
    county_name.append(current_county_name)
    county_witch_num.append(county_witches[i])
    county_latitude.append(county_latitude_dict[current_county_name])
    county_longitude.append(county_longitude_dict[current_county_name])
data_df = pd.DataFrame({
    'name': county_name,
    'case number': county_witch_num,
    'latitude': county_latitude,
    'longitude': county_longitude,
})
data_df['case number'] = data_df['case number'].astype(float)
data_df = data_df.dropna().reset_index(drop=True) # remove the counties with na values and reset the index
data_df
# Out:
#              name  case number   latitude  longitude
# 0        Aberdeen        175.0  57.146262  -2.136575
# 1          Argyll          6.0  56.400600  -5.480700
# 2             Ayr        153.0  55.457393  -4.628716
# 3           Banff          9.0  57.666252  -2.524260
# 4         Berwick        126.0  55.781124  -2.011552
# 5            Bute         54.0  55.827400  -5.093600
# 6       Caithness         52.0  58.438900  -3.093700
# 7     Clackmannan         18.0  56.108159  -3.747183
# 8        Cromarty          2.0  57.680600  -4.034700
# 9        Dumfries         78.0  55.068632  -3.608237
# 10      Dunbarton         25.0  56.833010  -4.180209
# 11      Edinburgh        374.0  55.928260  -3.275582
# 12          Elgin         28.0  57.648022  -3.320025
# 13           Fife        382.0  56.253397  -3.134239
# 14         Forfar         82.0  56.639836  -2.893115
# 15     Haddington        543.0  55.955755  -2.783795
# 16      Inverness         45.0  57.479549  -4.237208
# 17     Kincardine          2.0  56.068975  -3.715198
# 18        Kinross          7.0  56.211141  -3.425103
# 19  Kirkcudbright         35.0  54.835888  -4.049153
# 20         Lanark         77.0  55.674898  -3.773292
# 21     Linlithgow        114.0  55.971600  -3.602600
# 22          Nairn         55.0  57.585033  -3.869079
# 23         Orkney         72.0  58.980900  -2.960500
# 24        Peebles         91.0  55.651467  -3.191026
# 25          Perth        109.0  56.395704  -3.435877
# 26        Renfrew        124.0  55.874645  -4.389173
# 27           Ross         74.0  56.833010  -4.180209
# 28        Selkirk         21.0  55.548073  -2.839351
# 29       Shetland         28.0  60.305229  -1.294066
# 30       Stirling         53.0  56.281067  -4.436736
# 31     Sutherland         15.0  58.249999  -4.499998
# 32        Wigtown         15.0  54.868426  -4.442783

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         33 non-null     object
#  1   case number  33 non-null     float64
#  2   latitude     33 non-null     float64
#  3   longitude    33 non-null     float64
# dtypes: float64(3), object(1)
# memory usage: 1.2+ KB

# %%
# Get the location of Scotland
Scotland = geolocator.geocode('Scotland')
Scotland
# Out:
# Location(Alba / Scotland, United Kingdom, (56.7861112, -4.1140518, 0.0))

# %%
# Create the map of Scotland. Zoom_start is smaller than Champaign map because we want to cover a larger area
Scotland_map = folium.Map(location=[Scotland.raw['lat'], Scotland.raw['lon']], zoom_start=6)
Scotland_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f96ade5136fe78b4609dfbc106b16837 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f96ade5136fe78b4609dfbc106b16837&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f96ade5136fe78b4609dfbc106b16837 = L.map(
#                 &quot;map_f96ade5136fe78b4609dfbc106b16837&quot;,
#                 {
#                     center: [56.7861112, -4.1140518],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a05b01d37b026600ebf23e9357ea03ba = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f96ade5136fe78b4609dfbc106b16837);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Add circles to the map, each representing the witch accused data of a county
for i in range(len(data_df)):
    folium.Circle(location = (data_df['latitude'][i], data_df['longitude'][i]),
                  radius = data_df['case number'][i]*100,
                  tooltip = data_df['name'][i]).add_to(Scotland_map)
Scotland_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f96ade5136fe78b4609dfbc106b16837 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f96ade5136fe78b4609dfbc106b16837&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f96ade5136fe78b4609dfbc106b16837 = L.map(
#                 &quot;map_f96ade5136fe78b4609dfbc106b16837&quot;,
#                 {
#                     center: [56.7861112, -4.1140518],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a05b01d37b026600ebf23e9357ea03ba = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f96ade5136fe78b4609dfbc106b16837);
#
#
#             var circle_7628e80e8cc740fa021c14c5db015080 = L.circle(
#                 [57.146262, -2.136575],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 17500.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f96ade5136fe78b4609dfbc106b16837);
#
#
#             circle_7628e80e8cc740fa021c14c5db015080.bindTooltip(
#                 `&lt;div&gt;
#                      Aberdeen
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_26ec4ba12049038ec40dc7d5247fed21 = L.circle(
#                 [56.4006, -5.4807],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 600.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f96ade5136fe78b4609dfbc106b16837);
#
#
#             circle_26ec4ba12049038ec40dc7d5247fed21.bindTooltip(
#                 `&lt;div&gt;
#                      Argyll
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_67f8d618a358b4ee41b47f078fc5c695 = L.circle(
#                 [55.457393, -4.628716],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15300.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f96ade5136fe78b4609dfbc106b16837);
#
#
#             circle_67f8d618a358b4ee41b47f078fc5c695.bindTooltip(
#                 `&lt;div&gt;
#                      Ayr
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_b98eaadb6bea83fcbea0e39f9952a49e = L.circle(
#                 [57.666252, -2.52426],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 900.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f96ade5136fe78b4609dfbc106b16837);
#
#
#             circle_b98eaadb6bea83fcbea0e39f9952a49e.bindTooltip(
#                 `&lt;div&gt;
#                      Banff
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_4634590194470afdeec23ec63ba39864 = L.circle(
#                 [55.781124, -2.011552],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 12600.

# %% [markdown]
# # Task 3

# %%
# Recreate the map of Scottish witchcraft. First, reload the map with the location of Scottish capital "Edinburgh",
# and set the zoom_start as 7 to focus on the surrounding area of the city. Then add the data of each county into the new map,
# but the radius will be 1000*the square root (this can be obtained by importing "math" and use "math.sqrt") of the case number,
# to get a smoothed result. Besides, add popup according to the format "County_name Case Number: number"
# (e.g., Edinburgh Case Number: 374.0), and set "fill" as True. Finally display the new map.

import math

Edinburgh = geolocator.geocode('Edinburgh, Scotland')


Scotland_map = folium.Map(location=[Edinburgh.latitude, Edinburgh.longitude], zoom_start=7)

for i in range(len(data_df)):
    radius = 1000 * math.sqrt(data_df['case number'][i])
    popup_text = f"{data_df['name'][i]} Case Number: {data_df['case number'][i]}"
    folium.Circle(location=(data_df['latitude'][i], data_df['longitude'][i]), radius=radius, popup=popup_text, fill=True,).add_to(Scotland_map)

Scotland_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1e08bf45698776ae7b5814557b4dfd6a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1e08bf45698776ae7b5814557b4dfd6a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1e08bf45698776ae7b5814557b4dfd6a = L.map(
#                 &quot;map_1e08bf45698776ae7b5814557b4dfd6a&quot;,
#                 {
#                     center: [55.9533456, -3.1883749],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1c39bd17bbf1ca4f0b67aa13908dff6b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1e08bf45698776ae7b5814557b4dfd6a);
#
#
#             var circle_3fe6c5c045518f77303187dbbe7e051e = L.circle(
#                 [57.146262, -2.136575],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 13228.756555322952, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1e08bf45698776ae7b5814557b4dfd6a);
#
#
#         var popup_3883b7fd965d808c60955ac6d953ed88 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e49a3f7e47256ddd0a7423f715c5fa13 = $(`&lt;div id=&quot;html_e49a3f7e47256ddd0a7423f715c5fa13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Aberdeen Case Number: 175.0&lt;/div&gt;`)[0];
#                 popup_3883b7fd965d808c60955ac6d953ed88.setContent(html_e49a3f7e47256ddd0a7423f715c5fa13);
#
#
#
#         circle_3fe6c5c045518f77303187dbbe7e051e.bindPopup(popup_3883b7fd965d808c60955ac6d953ed88)
#         ;
#
#
#
#
#             var circle_5ea5f74fcee32f09ad4a0a34cfec031b = L.circle(
#                 [56.4006, -5.4807],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2449.489742783178, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1e08bf45698776ae7b5814557b4dfd6a);
#
#
#         var popup_bed07d2ed143f44e6fa45e0bf110b25c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b1886bdf5eebb877476764f021902cc9 = $(`&lt;div id=&quot;html_b1886bdf5eebb877476764f021902cc9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Argyll Case Number: 6.0&lt;/div&gt;`)[0];
#                 popup_bed07d2ed143f44e6fa45e0bf110b25c.setContent(html_b1886bdf5eebb877476764f021902cc9);
#
#
#
#         circle_5ea5f74fcee32f09ad4a0a34cfec031b.bindPopup(popup_bed07d2ed143f44e6fa45e0bf110b25c)
#         ;
#
#
#
#
#             var circle_9ae1a36396192c2d066ed75be5de4409 = L.circle(
#                 [55.457393, -4.628716],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 12369.316876852981, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1e08bf45698776ae7b5814557b4dfd6a);
#
#
#         var popup_41a5679c4ef1e0efcce98c20cd899e88 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f8c675071cde59a3599b01c48d79bab8 = $(`&lt;div id=&quot;html_f8c675071cde59a3599b01c48d79bab8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ayr Case Number: 153.0&lt;/div&gt;`)[0];
#                 popup_41a5679c4ef1e0efcce98c20cd899e88.setContent(html_f8c675071cde59a3599b01c48d79bab8);
#
#
#
#         circle_9ae1a36396192c2d066ed75be5de4409.bindPopup(popup_41a5679c4ef1e0efcce98c20cd899e88)
#         ;
#
#
#
#
#             var circle_4a6c40fd37f4aa006906062c1b4b9b39 = L.circle(
#                 [57.666252, -2.52426],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null

# %% [markdown]
# # Customize Map Backgrounds

# %%
# Using titles in folium
folium.Map(location=[Scotland.raw['lat'], Scotland.raw['lon']], tiles = 'cartodbpositron', zoom_start=6)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_36ef2048dff906eaab29d4f6bf2ce928 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_36ef2048dff906eaab29d4f6bf2ce928&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_36ef2048dff906eaab29d4f6bf2ce928 = L.map(
#                 &quot;map_36ef2048dff906eaab29d4f6bf2ce928&quot;,
#                 {
#                     center: [56.7861112, -4.1140518],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8b64f64036b918e5b59935ce963a9423 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_36ef2048dff906eaab29d4f6bf2ce928);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Using external background
folium.Map(location=[Scotland.raw['lat'], Scotland.raw['lon']],
           zoom_start=4,
           tiles='http://services.arcgisonline.com/arcgis/rest/services/NatGeo_World_Map/MapServer/tile/{z}/{y}/{x}',
           attr="Sources: National Geographic, Esri, Garmin, HERE, UNEP-WCMC, USGS, NASA, ESA, METI, NRCAN, GEBCO, NOAA, INCREMENT P")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bd9330ac1e8ab6cacc3a2a7bed3c71d2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bd9330ac1e8ab6cacc3a2a7bed3c71d2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bd9330ac1e8ab6cacc3a2a7bed3c71d2 = L.map(
#                 &quot;map_bd9330ac1e8ab6cacc3a2a7bed3c71d2&quot;,
#                 {
#                     center: [56.7861112, -4.1140518],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b580a9cdaca84253f1951f691f79178e = L.tileLayer(
#                 &quot;http://services.arcgisonline.com/arcgis/rest/services/NatGeo_World_Map/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Sources: National Geographic, Esri, Garmin, HERE, UNEP-WCMC, USGS, NASA, ESA, METI, NRCAN, GEBCO, NOAA, INCREMENT P&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bd9330ac1e8ab6cacc3a2a7bed3c71d2);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# And this not necessarily need to be real world...
folium.Map(location=[0, 30],
           zoom_start=4, min_zoom=4, max_zoom=10,
           max_bounds=True,
           min_lon=0, max_lon=70, min_lat=-40, max_lat=40,
           tiles='https://cartocdn-gusc.global.ssl.fastly.net//ramirocartodb/api/v1/map/named/tpl_756aec63_3adb_48b6_9d14_331c6cbc47cf/all/{z}/{x}/{y}.png',
           attr='Textures and Icons from https://www.textures.com/ & https://thenounproject.com/')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_890f3b2dee05d447eb0e149bbe027e91 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_890f3b2dee05d447eb0e149bbe027e91&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_890f3b2dee05d447eb0e149bbe027e91 = L.map(
#                 &quot;map_890f3b2dee05d447eb0e149bbe027e91&quot;,
#                 {
#                     center: [0.0, 30.0],
#                     crs: L.CRS.EPSG3857,
#                     maxBounds: [[-40, 0], [40, 70]],
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_25015ef55afc27f0ed312dc4a34ca375 = L.tileLayer(
#                 &quot;https://cartocdn-gusc.global.ssl.fastly.net//ramirocartodb/api/v1/map/named/tpl_756aec63_3adb_48b6_9d14_331c6cbc47cf/all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Textures and Icons from https://www.textures.com/ \u0026 https://thenounproject.com/&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 10, &quot;maxZoom&quot;: 10, &quot;minZoom&quot;: 4, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_890f3b2dee05d447eb0e149bbe027e91);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Geojson

# %%
# US states geojson file (obtained from https://github.com/python-visualization/folium/blob/main/examples/data/us-states.json)
US_states = "Data/us-states.json"

# %%
# Include the US States boundaries in the US Map
US_map = folium.Map(location=[42, -102], zoom_start=4)

folium.Choropleth(
    geo_data = US_states,
).add_to(US_map)

US_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_174dbc0b7edf8d34487225f766b13f5c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_174dbc0b7edf8d34487225f766b13f5c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_174dbc0b7edf8d34487225f766b13f5c = L.map(
#                 &quot;map_174dbc0b7edf8d34487225f766b13f5c&quot;,
#                 {
#                     center: [42.0, -102.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a67829b9cb244d64582294134634dcd2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_174dbc0b7edf8d34487225f766b13f5c);
#
#
#             var choropleth_9d3bc873c9049fd39e7f0826141f58b8 = L.featureGroup(
#                 {}
#             ).addTo(map_174dbc0b7edf8d34487225f766b13f5c);
#
#
#         function geo_json_2f7d3de8ee78f17def987adced78ad66_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_2f7d3de8ee78f17def987adced78ad66_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_2f7d3de8ee78f17def987adced78ad66 = L.geoJson(null, {
#                 onEachFeature: geo_json_2f7d3de8ee78f17def987adced78ad66_onEachFeature,
#
#                 style: geo_json_2f7d3de8ee78f17def987adced78ad66_styler,
#         });
#
#         function geo_json_2f7d3de8ee78f17def987adced78ad66_add (data) {
#             geo_json_2f7d3de8ee78f17def987adced78ad66
#                 .addData(data)
#                 .addTo(choropleth_9d3bc873c9049fd39e7f0826141f58b8);
#         }
#             geo_json_2f7d3de8ee78f17def987adced78ad66_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.359296, 35.00118], [-85.606675, 34.984749], [-85.431413, 34.124869], [-85.184951, 32.859696], [-85.069935, 32.580372], [-84.960397, 32.421541], [-85.004212, 32.322956], [-84.889196, 32.262709], [-85.058981, 32.13674], [-85.053504, 32.01077], [-85.141136, 31.840985], [-85.042551, 31.539753], [-85.113751, 31.27686], [-85.004212, 31.003013], [-85.497137, 30.997536], [-87.600282, 30.997536], [-87.633143, 30.86609], [-87.408589, 30.674397], [-87.446927, 30.510088], [-87.37025, 30.427934], [-87.518128, 30.280057], [-87.655051, 30.247195], [-87.90699, 30.411504], [-87.934375, 30.657966], [-88.011052, 30.685351], [-88.10416, 30.499135], [-88.137022, 30.318396], [-88.394438, 30.367688], [-88.471115, 31.895754], [-88.241084, 33.796253], [-88.098683, 34.891641], [-88.202745, 34.995703], [-87.359296, 35.00118]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;AL&quot;, &quot;properties&quot;: {&quot;name&quot;: &quot;Alabama&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-131.602021, 55.117982], [-131.569159, 55.28229], [-131.355558, 55.183705], [-131.38842, 55.01392], [-131.645836, 55.035827], [-131.602021, 55.117982]]], [[[-131.832052, 55.42469], [-131.645836, 55.304197], [-131.749898, 55.128935], [-131.832052, 55.189182], [-131.832052, 55.42469]]], [[[-132.976733, 56.437924], [-132.735747, 56.459832], [-132.631685, 56.421493], [-132.664547, 56.273616], [-132.878148, 56.240754], [-133.069841, 56.333862], [-132.976733, 56.437924]]], [[[-133.595627, 56.350293], [-133.162949, 56.317431], [-133.05341, 56.125739], [-132.620732, 55.912138], [-132.472854, 55.780691], [-132.4619, 55.671152], [-132.357838, 55.649245], [-132.341408, 55.506844], [-132.166146, 55.364444], [-132.144238, 55.238474], [-132.029222, 55.276813], [-131.97993, 55.178228], [-131.958022, 54.789365], [-132.029222, 54.701734], [-132.308546, 54.718165], [-132.385223, 54.915335], [-132.483808, 54.898904], [-132.686455, 55.046781], [-132.746701, 54.997489], [-132.916486, 55.046781], [-132.889102, 54.898904], [-132.73027, 54.937242], [-132.626209, 54.882473], [-132.675501, 54.679826], [-132.867194, 54.701734], [-133.157472, 54.95915], [-133.239626, 55.090597], [-133.223195, 55.22752], [-133.453227, 55.216566], [-133.453227, 55.320628], [-133.277964, 55.331582], [-133.102702, 55.42469], [-133.17938, 55.588998], [-133.387503, 55.62186], [-133.420365, 55.884753], [-133.497042, 56.0162], [-133.639442, 55.923092], [-133.694212, 56.070969], [-133.546335, 56.142169], [-133.666827, 56.311955], [-133.595627, 56.350293]]], [[[-133.738027, 55.556137], [-133.546335, 55.490413], [-133.414888, 55.572568], [-133.283441, 55.534229], [-133.420365, 55.386352], [-133.633966, 55.430167], [-133.738027, 55.556137]]], [[[-133.907813, 56.930849], [-134.050213, 5

# %%
# US unemployment rate data (obtained from https://www.kaggle.com/datasets/aniruddhasshirahatti/us-unemployment-dataset-2010-2020?resource=download)
US_unemployment = pd.read_csv("Data/unemployment_data_us_state.csv")
US_unemployment
# Out:
#              State  Unemployment_Rate_Jan_20  Unemployment_Rate_Feb_20  \
# 0          Alabama                       2.7                       2.7
# 1           Alaska                       6.0                       5.8
# 2          Arizona                       4.5                       4.5
# 3         Arkansas                       3.5                       3.9
# 4       California                       3.9                       2.5
# 5         Colorado                       2.5                       2.8
# 6      Connecticut                       3.7                       3.9
# 7         Delaware                       4.0                       5.2
# 8             D.C.                       5.2                       2.8
# 9          Florida                       2.8                       3.1
# 10         Georgia                       3.1                       2.7
# 11          Hawaii                       2.7                       2.7
# 12           Idaho                       2.8                       3.4
# 13        Illinois                       3.5                       3.1
# 14         Indiana                       3.1                       2.8
# 15            Iowa                       2.8                       3.1
# 16          Kansas                       3.1                       4.2
# 17        Kentucky                       4.3                       5.2
# 18       Louisiana                       5.1                       3.2
# 19           Maine                       3.1                       3.3
# 20        Maryland                       3.3                       2.8
# 21   Massachusetts                       2.8                       3.6
# 22        Michigan                       3.8                       3.1
# 23       Minnesota                       3.2                       5.4
# 24     Mississippi                       5.5                       3.5
# 25        Missouri                       3.5                       3.5
# 26         Montana                       3.5                       2.9
# 27        Nebraska                       3.9                       3.6
# 28          Nevada                       3.6                       3.6
# 29   New Hampshire                       2.6                       3.8
# 30      New Jersey                       3.8                       4.8
# 31      New Mexico                       4.8                       3.7
# 32        New York                       3.8                       3.6
# 33  North Carolina                       3.6                       2.2
# 34    North Dakota                       2.3                       4.2
# 35            Ohio                       4.1                       3.2
# 36        Oklahoma                       3.3                       3.3
# 37          Oregon                       3.3                       4.7
# 38    Pennsylvania                       4.7                       3.4
# 39    Rhode Island                       3.1                       2.5
# 40  South Carolina                       2.4                       3.3
# 41    South Dakota                       3.4                       3.4
# 42       Tennessee                       3.3                       3.5
# 43           Texas                       4.5                       2.5
# 44            Utah                       2.5                       3.4
# 45         Vermont                       2.4                       2.6
# 46        Virginia                       2.7                       3.8
# 47      Washington                       3.9                       4.9
# 48   West Virginia                       5.0                       3.7
# 49       Wisconsin                       3.5                       2.7
# 50         Wyoming                       3.7                       5.8
#
#     Unemployment_Rate_Mar_20
# 0                        3.5
# 1                        5.6
# 2                        5.5
# 3                        4.8
# 4                        5.3
# 5                        4.5
# 6                        3.7
# 7                        5.1
# 8                        6.0
# 9                        4.3
# 10                       4.2
# 11                       2.6
# 12                       2.6
# 13                       4.6
# 14                       3.2
# 15                       3.7
# 16                       3.1
# 17                       5.8
# 18                       6.1
# 19                       3.2
# 20                       3.3
# 21                       2.9
# 22                       4.1
# 23                       3.1
# 24                       5.3
# 25                       4.5
# 26                       3.5
# 27                       4.2
# 28                       6.3
# 29                       2.6
# 30                       3.8
# 31                       5.9
# 32                       4.5
# 33                       4.4
# 34                       2.2
# 35                       5.5
# 36                       3.1
# 37                       3.3
# 38                       6.0
# 39                       4.6
# 40                       2.6
# 41                       3.3
# 42                       3.5
# 43                       4.7
# 44                       3.6
# 45                       3.2
# 46                       3.3
# 47                       5.1
# 48                       6.1
# 49                       3.4
# 50                       3.7

# %%
# Change column name to match the geojson data
US_unemployment = US_unemployment.rename(columns={'State': 'name'})
US_unemployment
# Out:
#               name  Unemployment_Rate_Jan_20  Unemployment_Rate_Feb_20  \
# 0          Alabama                       2.7                       2.7
# 1           Alaska                       6.0                       5.8
# 2          Arizona                       4.5                       4.5
# 3         Arkansas                       3.5                       3.9
# 4       California                       3.9                       2.5
# 5         Colorado                       2.5                       2.8
# 6      Connecticut                       3.7                       3.9
# 7         Delaware                       4.0                       5.2
# 8             D.C.                       5.2                       2.8
# 9          Florida                       2.8                       3.1
# 10         Georgia                       3.1                       2.7
# 11          Hawaii                       2.7                       2.7
# 12           Idaho                       2.8                       3.4
# 13        Illinois                       3.5                       3.1
# 14         Indiana                       3.1                       2.8
# 15            Iowa                       2.8                       3.1
# 16          Kansas                       3.1                       4.2
# 17        Kentucky                       4.3                       5.2
# 18       Louisiana                       5.1                       3.2
# 19           Maine                       3.1                       3.3
# 20        Maryland                       3.3                       2.8
# 21   Massachusetts                       2.8                       3.6
# 22        Michigan                       3.8                       3.1
# 23       Minnesota                       3.2                       5.4
# 24     Mississippi                       5.5                       3.5
# 25        Missouri                       3.5                       3.5
# 26         Montana                       3.5                       2.9
# 27        Nebraska                       3.9                       3.6
# 28          Nevada                       3.6                       3.6
# 29   New Hampshire                       2.6                       3.8
# 30      New Jersey                       3.8                       4.8
# 31      New Mexico                       4.8                       3.7
# 32        New York                       3.8                       3.6
# 33  North Carolina                       3.6                       2.2
# 34    North Dakota                       2.3                       4.2
# 35            Ohio                       4.1                       3.2
# 36        Oklahoma                       3.3                       3.3
# 37          Oregon                       3.3                       4.7
# 38    Pennsylvania                       4.7                       3.4
# 39    Rhode Island                       3.1                       2.5
# 40  South Carolina                       2.4                       3.3
# 41    South Dakota                       3.4                       3.4
# 42       Tennessee                       3.3                       3.5
# 43           Texas                       4.5                       2.5
# 44            Utah                       2.5                       3.4
# 45         Vermont                       2.4                       2.6
# 46        Virginia                       2.7                       3.8
# 47      Washington                       3.9                       4.9
# 48   West Virginia                       5.0                       3.7
# 49       Wisconsin                       3.5                       2.7
# 50         Wyoming                       3.7                       5.8
#
#     Unemployment_Rate_Mar_20
# 0                        3.5
# 1                        5.6
# 2                        5.5
# 3                        4.8
# 4                        5.3
# 5                        4.5
# 6                        3.7
# 7                        5.1
# 8                        6.0
# 9                        4.3
# 10                       4.2
# 11                       2.6
# 12                       2.6
# 13                       4.6
# 14                       3.2
# 15                       3.7
# 16                       3.1
# 17                       5.8
# 18                       6.1
# 19                       3.2
# 20                       3.3
# 21                       2.9
# 22                       4.1
# 23                       3.1
# 24                       5.3
# 25                       4.5
# 26                       3.5
# 27                       4.2
# 28                       6.3
# 29                       2.6
# 30                       3.8
# 31                       5.9
# 32                       4.5
# 33                       4.4
# 34                       2.2
# 35                       5.5
# 36                       3.1
# 37                       3.3
# 38                       6.0
# 39                       4.6
# 40                       2.6
# 41                       3.3
# 42                       3.5
# 43                       4.7
# 44                       3.6
# 45                       3.2
# 46                       3.3
# 47                       5.1
# 48                       6.1
# 49                       3.4
# 50                       3.7

# %%
# Visualize based on unemployment rate of January 2020
US_map = folium.Map(location=[42, -102], zoom_start=4)
folium.Choropleth(
    geo_data = US_states, # Geo_data to be used
    data = US_unemployment, # Data used for visualization
    columns = ['name', 'Unemployment_Rate_Jan_20'], # First column is the key to match, second column is the value to display
    key_on = 'feature.properties.name', # The matched key in geo_data
    fill_color = 'OrRd', # Seelct a color scheme
    line_opacity = 0.2, # Select line opacity
    legend_name= 'Unemployment Rate by State in January 2020', # Choose a name for the legend
).add_to(US_map)

US_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3a1ac174a5d8a15d3b93aa008ba4bc65 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3a1ac174a5d8a15d3b93aa008ba4bc65&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3a1ac174a5d8a15d3b93aa008ba4bc65 = L.map(
#                 &quot;map_3a1ac174a5d8a15d3b93aa008ba4bc65&quot;,
#                 {
#                     center: [42.0, -102.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6e7d6905370bea814653ffb9e9d07698 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3a1ac174a5d8a15d3b93aa008ba4bc65);
#
#
#             var choropleth_cf4f3ab9c82bd75deec4ac1e7cbaa156 = L.featureGroup(
#                 {}
#             ).addTo(map_3a1ac174a5d8a15d3b93aa008ba4bc65);
#
#
#         function geo_json_b841839f9231d4f451096384c767cfef_styler(feature) {
#             switch(feature.id) {
#                 case &quot;AL&quot;: case &quot;CO&quot;: case &quot;FL&quot;: case &quot;HI&quot;: case &quot;ID&quot;: case &quot;IA&quot;: case &quot;MA&quot;: case &quot;NH&quot;: case &quot;ND&quot;: case &quot;SC&quot;: case &quot;UT&quot;: case &quot;VT&quot;: case &quot;VA&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fef0d9&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;AK&quot;: case &quot;MS&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#b30000&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;AZ&quot;: case &quot;KY&quot;: case &quot;PA&quot;: case &quot;TX&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fc8d59&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;CA&quot;: case &quot;CT&quot;: case &quot;DE&quot;: case &quot;MI&quot;: case &quot;NE&quot;: case &quot;NV&quot;: case &quot;NJ&quot;: case &quot;NY&quot;: case &quot;NC&quot;: case &quot;OH&quot;: case &quot;WA&quot;: case &quot;WY&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fdbb84&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;LA&quot;: case &quot;NM&quot;: case &quot;WV&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#e34a33&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fdd49e&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_b841839f9231d4f451096384c767cfef_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_b841839f9231d4f451096384c767cfef = L.geoJson(null, {
#                 onEachFeature: geo_json_b841839f9231d4f451096384c767cfef_onEachFeature,
#
#                 style: geo_json_b841839f9231d4f451096384c767cfef_styler,
#         });
#
#         function geo_json_b841839f9231d4f451096384c767cfef_add (data) {
#             geo_json_b841839f9231d4f451096384c767cfef
#                 .addData(data)
#                 .addTo(choropleth_cf4f3ab9c82bd75deec4ac1e7cbaa156);
#         }
#             geo_json_b841839f9231d4f451096384c767cfef_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.359296, 35.00118], [-85.606675, 34.984749], [-85.431413, 34.124869], [-85.184951, 32.859696], [-85.069935, 32.580372], [-84.960397, 32.421541], [-85.004212, 32.322956], [-84.889196, 32.262709], [-85.058981, 32.13674], [-85.053504, 32.01077], [-85.141136, 31.840985], [-85.042551, 31.539753], [-85.113751, 31.27686], [-85.004212, 31.003013], [-85.497137, 30.997536], [-87.600282, 30.997536], [-87.633143, 30.86609], [-87.408589, 30.674397], [-87.446927, 30.510088], [-87.37025, 30.427934], [-87.518128, 30.280057], [-87.655051, 30.247195], [-87.90699, 30.411504], [-87.934375, 30.657966], [-88.011052, 30.685351], [-88.10416, 30.499135], [-88.137022, 30.318396], [-88.394438, 30.367688], [-88.471115, 31.895754], [-88.241084, 33.796253], [-88.098683, 34.891641], [-88.202745, 34.995703], [-87.359296, 35.00118]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;AL&quot;, &quot;properties&quot;: {&quot;name&quot;: &quot;Alabam

# %%
# Add tooltip to display the state names
tooltip = folium.features.GeoJson(
    US_states,
    tooltip=folium.features.GeoJsonTooltip(fields=['name'], localize=True)
                                )
US_map.add_child(tooltip)
US_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3a1ac174a5d8a15d3b93aa008ba4bc65 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3a1ac174a5d8a15d3b93aa008ba4bc65&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3a1ac174a5d8a15d3b93aa008ba4bc65 = L.map(
#                 &quot;map_3a1ac174a5d8a15d3b93aa008ba4bc65&quot;,
#                 {
#                     center: [42.0, -102.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6e7d6905370bea814653ffb9e9d07698 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3a1ac174a5d8a15d3b93aa008ba4bc65);
#
#
#             var choropleth_cf4f3ab9c82bd75deec4ac1e7cbaa156 = L.featureGroup(
#                 {}
#             ).addTo(map_3a1ac174a5d8a15d3b93aa008ba4bc65);
#
#
#         function geo_json_b841839f9231d4f451096384c767cfef_styler(feature) {
#             switch(feature.id) {
#                 case &quot;AL&quot;: case &quot;CO&quot;: case &quot;FL&quot;: case &quot;HI&quot;: case &quot;ID&quot;: case &quot;IA&quot;: case &quot;MA&quot;: case &quot;NH&quot;: case &quot;ND&quot;: case &quot;SC&quot;: case &quot;UT&quot;: case &quot;VT&quot;: case &quot;VA&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fef0d9&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;AK&quot;: case &quot;MS&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#b30000&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;AZ&quot;: case &quot;KY&quot;: case &quot;PA&quot;: case &quot;TX&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fc8d59&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;CA&quot;: case &quot;CT&quot;: case &quot;DE&quot;: case &quot;MI&quot;: case &quot;NE&quot;: case &quot;NV&quot;: case &quot;NJ&quot;: case &quot;NY&quot;: case &quot;NC&quot;: case &quot;OH&quot;: case &quot;WA&quot;: case &quot;WY&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fdbb84&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;LA&quot;: case &quot;NM&quot;: case &quot;WV&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#e34a33&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fdd49e&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_b841839f9231d4f451096384c767cfef_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_b841839f9231d4f451096384c767cfef = L.geoJson(null, {
#                 onEachFeature: geo_json_b841839f9231d4f451096384c767cfef_onEachFeature,
#
#                 style: geo_json_b841839f9231d4f451096384c767cfef_styler,
#         });
#
#         function geo_json_b841839f9231d4f451096384c767cfef_add (data) {
#             geo_json_b841839f9231d4f451096384c767cfef
#                 .addData(data)
#                 .addTo(choropleth_cf4f3ab9c82bd75deec4ac1e7cbaa156);
#         }
#             geo_json_b841839f9231d4f451096384c767cfef_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.359296, 35.00118], [-85.606675, 34.984749], [-85.431413, 34.124869], [-85.184951, 32.859696], [-85.069935, 32.580372], [-84.960397, 32.421541], [-85.004212, 32.322956], [-84.889196, 32.262709], [-85.058981, 32.13674], [-85.053504, 32.01077], [-85.141136, 31.840985], [-85.042551, 31.539753], [-85.113751, 31.27686], [-85.004212, 31.003013], [-85.497137, 30.997536], [-87.600282, 30.997536], [-87.63

# %% [markdown]
# # Task 4

# %%
# Recreate the map of US unemployment. First, create a column 'Unemployment_Rate_2020_spring' in the DataFrame, as the average
# of the unemployment rates of January, Feburary, and March. Then, reload the map using the geocode of "USA" in gelocator.
# Next, create folium.Choropleth, and set the values of the newly-created column Unemployment_Rate_2020_spring, fill_color as
# "GnBu" (green and blue), and line_opacity as 0.3. Also, change the legend name to reflect the change of data.
# Finally, add the State names as tooltip, and display the new map.

US_unemployment['Unemployment_Rate_2020_spring'] = (US_unemployment['Unemployment_Rate_Jan_20']+
                                                  US_unemployment['Unemployment_Rate_Feb_20']+
                                                  US_unemployment['Unemployment_Rate_Mar_20'])/3
USA = geolocator.geocode('USA')

US_map = folium.Map(location=[USA.latitude, USA.longitude], zoom_start=4)


folium.Choropleth(
    geo_data = US_states,
    data = US_unemployment, 
    columns = ['name', 'Unemployment_Rate_2020_spring'],
    key_on = 'feature.properties.name', 
    fill_color = 'GnBu', 
    line_opacity = 0.3, 
    legend_name= 'Unemployment Rate spring 2020',).add_to(US_map)

tooltip = folium.features.GeoJson(
    US_states,
    tooltip=folium.features.GeoJsonTooltip(fields=['name'], localize=True)
                                )
US_map.add_child(tooltip)
US_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d5d12b1d3cc551da141bd21b6d78e0a6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d5d12b1d3cc551da141bd21b6d78e0a6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d5d12b1d3cc551da141bd21b6d78e0a6 = L.map(
#                 &quot;map_d5d12b1d3cc551da141bd21b6d78e0a6&quot;,
#                 {
#                     center: [39.7837304, -100.445882],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7ace1b228552452f7f159b7df1627daf = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d5d12b1d3cc551da141bd21b6d78e0a6);
#
#
#             var choropleth_b32ecbcde6751ce278bcd687a3941d21 = L.featureGroup(
#                 {}
#             ).addTo(map_d5d12b1d3cc551da141bd21b6d78e0a6);
#
#
#         function geo_json_f7e2767a894b6d8eb281793aec7abc01_styler(feature) {
#             switch(feature.id) {
#                 case &quot;AL&quot;: case &quot;HI&quot;: case &quot;ID&quot;: case &quot;IN&quot;: case &quot;MD&quot;: case &quot;MA&quot;: case &quot;NH&quot;: case &quot;ND&quot;: case &quot;SC&quot;: case &quot;UT&quot;: case &quot;VT&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f0f9e8&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case &quot;AK&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#0868ac&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case &quot;AZ&quot;: case &quot;DE&quot;: case &quot;KY&quot;: case &quot;LA&quot;: case &quot;MS&quot;: case &quot;NM&quot;: case &quot;WV&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#43a2ca&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case &quot;AR&quot;: case &quot;CA&quot;: case &quot;CT&quot;: case &quot;IL&quot;: case &quot;MN&quot;: case &quot;MO&quot;: case &quot;NE&quot;: case &quot;NJ&quot;: case &quot;NY&quot;: case &quot;OR&quot;: case &quot;TX&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#a8ddb5&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case &quot;NV&quot;: case &quot;OH&quot;: case &quot;PA&quot;: case &quot;WA&quot;: case &quot;WY&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#7bccc4&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ccebc5&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_f7e2767a894b6d8eb281793aec7abc01_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_f7e2767a894b6d8eb281793aec7abc01 = L.geoJson(null, {
#                 onEachFeature: geo_json_f7e2767a894b6d8eb281793aec7abc01_onEachFeature,
#
#                 style: geo_json_f7e2767a894b6d8eb281793aec7abc01_styler,
#         });
#
#         function geo_json_f7e2767a894b6d8eb281793aec7abc01_add (data) {
#             geo_json_f7e2767a894b6d8eb281793aec7abc01
#                 .addData(data)
#                 .addTo(choropleth_b32ecbcde6751ce278bcd687a3941d21);
#         }
#             geo_json_f7e2767a894b6d8eb281793aec7abc01_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.359296, 35.00118], [-85.606675, 34.984749], [-85.431413, 34.124869], [-85.184951, 32.859696], [-85.069935, 32.580372], [-84.960397, 32.421541], [-85.004212, 32.322956], [-84.889196, 32.262709], [-85.058981, 32.13674], [-85.053504, 32.01077], [-85.141136, 31.840985], [-85.042551, 31.539753], [-85.113751, 31.27686], [-85.004212, 31.003013], [-85.497137, 30.997536],

# %% [markdown]
# # Task 5

# %% [markdown]
# This task is designed to enhance your critical analysis and interpretation skills when dealing with visualizations.<br>Write a short paragraph in the following cell for Task 3 to draw conclusions from the data visualization of the geographical distribution of witchcraft cases in Scotland. Additionally, make some assumptions regarding the reasons behind this distribution.<br>Then, write a separate paragraph in the next cell for Task 4 to examine areas in the US with higher or lower unemployment rates in Spring 2020. Also, make assumptions regarding the reasons for this distribution.<br>Finally, remember to convert the cell type for both cells to "markdown" and execute it.

# %% [markdown]
# For the distribution of witchcraft cases in Scotland we can see that through the congregation of major roads/rivers that these are cities. This including the fact that one of them is for sure the capital of Edinburgh this makes sense. As the increase in cases in these areas would be because of the higher populations compared to the countryside/rural areas of scotland. Individuals tend to congregate more leading to altercations or accusations of witchcraft. Also there may be more individuals interested in practicing witchcraft but many of these cases were probably be false cases of witchcraft. But these larger populations in cities is why we see more cases like in Edinburgh, the surrounding areas, and Glasgow.

# %% [markdown]
# The reason for this distribution may be more nuanced. We see areas with the highest rates of unemployment were states like West Virginia, Virginia, Arizona, Missippi, Lousiana, and Alaska. Many of these states with Arizona and Virginia being outliers have a tendency to be pretty rural states and West Virginia/Missippi are the poorest states in the country. Since they are so poor with a lacking in Urban development there may less job opportunities as businesses don't want to set up in these states also with lower populations. This also pertains to Alaska as they lack population and don't share the same benefit of interstate commerce like other states can benefit from due to Alaska's isolated nature. We can see support for this trend as the most urban, wealthy, and large states like California, Texas, New York, and Illinois all are in the lesser portion of states suffering from unemployment.
#
# Reference for some of my state assumptions: https://en.wikipedia.org/wiki/List_of_U.S._states_and_territories_by_GDP#:~:text=GDP%20per%20capita%20also%20varied,recorded%20the%20three%20lowest%20GDP
